# %%
# Local Machine and Colab
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# Colab
from google.colab import drive
drive.mount('/content/drive')

import shutil

# WDNet files
drive_path_WDNet = '/content/drive/Othercomputers/HUAVSN/GitHub/pet_WDNet'
colab_path_WDNet = '/content/pet_WDNet'
shutil.copytree(drive_path_WDNet, colab_path_WDNet)
print('WDNet was copied to Colab')

# Dataset
dataset_zip = 'data_CLWD.zip'
drive_path_CLWD = os.path.join('/content/drive/MyDrive/ML_datasets/',dataset_zip)
colab_path_CLWD = os.path.join('/content/',dataset_zip)
shutil.copyfile(drive_path_CLWD, colab_path_CLWD)
print('Dataset was copied to Colab')
# Out:
# Mounted at /content/drive
# WDNet was copied to Colab
# Dataset was copied to Colab

# %%
pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# !unzip data_CLWD.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: data_CLWD/train/Watermark_free_image/59682.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59683.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59684.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59685.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59686.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59687.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59688.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59689.jpg
#  extracting: data_CLWD/train/Watermark_free_image/5969.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59690.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59691.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59692.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59693.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59694.jpg
#  extracting: data_CLWD/train/Watermark_free_image/59695.jpg
# ...

# %%
os.chdir('pet_WDNet')
os.getcwd()
# Out:
# '/content/pet_WDNet'

# %%
import WDNet
import torch

torch.cuda.empty_cache()
print(torch.cuda.is_available())
# Out:
# True

# %%
args ={}
args['epoch'] = 10
args['batch_size'] = 12 # 12 for 16Gb
args['save_dir'] = '/content/drive/Othercomputers/HUAVSN/ML_models/model_WDNet'
args['dataset'] = '/content/data_CLWD'
args['gpu_mode'] = torch.cuda.is_available()
args['dataloader_workers'] = 0 # 0 if windows
args['lrG'] = 0.0002
args['lrD'] = 0.0002
args['beta1'] = 0.5
args['beta2'] = 0.999
args
# Out:
# {'epoch': 10,
#  'batch_size': 12,
#  'save_dir': '/content/drive/Othercomputers/HUAVSN/ML_models/model_WDNet',
#  'dataset': '/content/data_CLWD',
#  'gpu_mode': True,
#  'dataloader_workers': 0,
#  'lrG': 0.0002,
#  'lrD': 0.0002,
#  'beta1': 0.5,
#  'beta2': 0.999}

# %%
wdnet = WDNet.WDNet(args)
# Out:
# Model initiated. Do not forget load state dicts if you need pretrained model

# %%
wdnet.load()
# Out:
# Model loaded from /content/drive/Othercomputers/HUAVSN/ML_models/model_WDNet, prefix=False

# %%
wdnet.train(prev_train_hist=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:06<00:00, 87.3MB/s]
# 2024-07-12_00-24-07 Start training!
# ...
